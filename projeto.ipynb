# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_churn = pd.read_csv('data.csv')
data_churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
final_data = pd.get_dummies(data=data_churn, columns=['gender',
                                                      'SeniorCitizen',
                                                      'MultipleLines',
                                                      'InternetService',
                                                      'PaymentMethod', 
                                                      'Contract', 
                                                      'Partner',
                                                      'Dependents',
                                                      'PhoneService',
                                                      'OnlineSecurity', 
                                                      'OnlineBackup',
                                                      'DeviceProtection', 
                                                      'TechSupport',
                                                      'StreamingTV',
                                                      'StreamingMovies', 'PaperlessBilling'], drop_first=True)

# %%
final_data.head()
# Out:
#    customerID  tenure  MonthlyCharges TotalCharges Churn  gender_Male  \
# 0  7590-VHVEG       1           29.85        29.85    No        False
# 1  5575-GNVDE      34           56.95       1889.5    No         True
# 2  3668-QPYBK       2           53.85       108.15   Yes         True
# 3  7795-CFOCW      45           42.30      1840.75    No         True
# 4  9237-HQITU       2           70.70       151.65   Yes        False
#
#    SeniorCitizen_1  MultipleLines_No phone service  MultipleLines_Yes  \
# 0            False                            True              False
# 1            False                           False              False
# 2            False                           False              False
# 3            False                            True              False
# 4            False                           False              False
#
#    InternetService_Fiber optic  ...  OnlineBackup_Yes  \
# 0                        False  ...              True
# ...

# %%
sns.heatmap(final_data.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
final_data.head()
# Out:
#    customerID  tenure  MonthlyCharges TotalCharges Churn  gender_Male  \
# 0  7590-VHVEG       1           29.85        29.85    No        False
# 1  5575-GNVDE      34           56.95       1889.5    No         True
# 2  3668-QPYBK       2           53.85       108.15   Yes         True
# 3  7795-CFOCW      45           42.30      1840.75    No         True
# 4  9237-HQITU       2           70.70       151.65   Yes        False
#
#    SeniorCitizen_1  MultipleLines_No phone service  MultipleLines_Yes  \
# 0            False                            True              False
# 1            False                           False              False
# 2            False                           False              False
# 3            False                            True              False
# 4            False                           False              False
#
#    InternetService_Fiber optic  ...  OnlineBackup_Yes  \
# 0                        False  ...              True
# ...

# %%
print(final_data.columns)
# Out:
# Index(['customerID', 'tenure', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'gender_Male', 'SeniorCitizen_1', 'MultipleLines_No phone service',
#        'MultipleLines_Yes', 'InternetService_Fiber optic',
#        'InternetService_No', 'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check',
#        'Contract_One year', 'Contract_Two year', 'Partner_Yes',
#        'Dependents_Yes', 'PhoneService_Yes',
#        'OnlineSecurity_No internet service', 'OnlineSecurity_Yes',
#        'OnlineBackup_No internet service', 'OnlineBackup_Yes',
#        'DeviceProtection_No internet service', 'DeviceProtection_Yes',
#        'TechSupport_No internet service', 'TechSupport_Yes',
#        'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No internet service', 'StreamingMovies_Yes',
#        'PaperlessBilling_Yes'],
#       dtype='str')

# %%
final_data.info(all)
# Out:
# <class 'pandas.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   customerID                             7032 non-null   str
#  1   tenure                                 7032 non-null   int64
#  2   MonthlyCharges                         7032 non-null   float64
#  3   TotalCharges                           7032 non-null   float64
#  4   Churn                                  7032 non-null   str
#  5   gender_Male                            7032 non-null   bool
#  6   SeniorCitizen_1                        7032 non-null   bool
#  7   MultipleLines_No phone service         7032 non-null   bool
#  8   MultipleLines_Yes                      7032 non-null   bool
#  9   InternetService_Fiber optic            7032 non-null   bool
#  10  InternetService_No                     7032 non-null   bool
# ...

# %%
sns.countplot(data =data_churn, x='Churn')
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
final_data['TotalCharges']
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: str

# %%
final_data['TotalCharges'] = pd.to_numeric(final_data['TotalCharges'], errors='coerce')

# %%
final_data['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
final_data.value_counts()
# Out:
# customerID  tenure  MonthlyCharges  TotalCharges  Churn  gender_Male  SeniorCitizen_1  MultipleLines_No phone service  MultipleLines_Yes  InternetService_Fiber optic  InternetService_No  PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  PaymentMethod_Mailed check  Contract_One year  Contract_Two year  Partner_Yes  Dependents_Yes  PhoneService_Yes  OnlineSecurity_No internet service  OnlineSecurity_Yes  OnlineBackup_No internet service  OnlineBackup_Yes  DeviceProtection_No internet service  DeviceProtection_Yes  TechSupport_No internet service  TechSupport_Yes  StreamingTV_No internet service  StreamingTV_Yes  StreamingMovies_No internet service  StreamingMovies_Yes  PaperlessBilling_Yes
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(final_data.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(11,7))
sns.countplot(x='Churn',data=final_data,palette='Set1')
# Out:
# C:\Users\ederq\AppData\Local\Temp\ipykernel_34012\364150457.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Churn',data=final_data,palette='Set1')
# <Axes: xlabel='Churn', ylabel='count'>

# %%
final_data = final_data.dropna()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(final_data.drop(labels=['customerID','Churn'], axis=1), final_data['Churn'],test_size=0.30)

# %%
X_train.head()
# Out:
#       tenure  MonthlyCharges  TotalCharges  gender_Male  SeniorCitizen_1  \
# 3551       1           79.60         79.60        False            False
# 5592      13           19.75        265.75         True            False
# 1323      71           24.65       1710.15        False            False
# 5423      13           80.85       1008.70         True            False
# 4088       7           73.60        520.00         True            False
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 3551                           False              False
# 5592                           False              False
# 1323                           False               True
# 5423                           False              False
# 4088                           False               True
#
#       InternetService_Fiber optic  InternetService_No  \
# 3551                         True               False
# 5592                        False                True
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=200)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.85      0.89      0.87      1592
#          Yes       0.61      0.52      0.56       518
#
#     accuracy                           0.80      2110
#    macro avg       0.73      0.70      0.72      2110
# weighted avg       0.79      0.80      0.79      2110

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[1422  170]
#  [ 251  267]]

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_LR = LogisticRegression(class_weight='balanced')

# %%
model_LR.fit(X_train,y_train)
# Out:
# c:\Users\ederq\OneDrive\Área de Trabalho\Estudos\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced')

# %%
pred_LR = model_LR.predict(X_test)

# %%
print(classification_report(y_test,pred_LR))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.92      0.74      0.82      1592
#          Yes       0.50      0.81      0.62       518
#
#     accuracy                           0.76      2110
#    macro avg       0.71      0.77      0.72      2110
# weighted avg       0.82      0.76      0.77      2110

# %%
print(confusion_matrix(y_test,pred_LR))
# Out:
# [[1180  412]
#  [ 101  417]]

# %%
y_prob = model_LR.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import precision_recall_curve

# %%
y_test = y_test.map({'No': 0, 'Yes': 1})

# %%
precision, recall, thresholds = precision_recall_curve(y_test, y_prob)

# %%
plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.show()

# %%
from sklearn.pipeline import Pipeline
import joblib

# %%
pipeline = Pipeline([
    ('model', model_LR)
    ])

# %%
pipeline.fit(X_train,y_train)
# Out:
# c:\Users\ederq\OneDrive\Área de Trabalho\Estudos\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('model', LogisticRegression(class_weight='balanced'))])

# %%
joblib.dump(pipeline,'churn_model.pkl')
# Out:
# ['churn_model.pkl']
